# %%
#pip install facebook-scraper

# %%
from facebook_scraper import get_posts
import couchdb
import json
import time

# %%
couch = couchdb.Server('http://jaela:654321@localhost:5984/')
nombredb = 'provincias'
db = couch[nombredb]

# %%
i=1
for post in get_posts('LassoGuillermo', pages=1000, extra_info=True):
    print(i)
    i=i+1
    time.sleep(5)
    
    id=post['post_id']
    doc={}
     
    doc['id']=id
    
    mydate=post['time']
    
    try:
        doc['texto']=post['text']
        doc['date']=mydate.timestamp()
        doc['likes']=post['likes']
        doc['comments']=post['comments']
        doc['shares']=post['shares']
        try:
            doc['reactions']=post['reactions']
        except:
            doc['reactions']={}

        doc['post_url']=post['post_url']
        db.save(doc)

    
        print("guardado exitosamente")

    except Exception as e:    
        print("no se pudo grabar:" + str(e))
# Out:
# 1
# guardado exitosamente
# 2
# guardado exitosamente
# 3
# guardado exitosamente
# 4
# guardado exitosamente
# 5
# guardado exitosamente
# 6
# guardado exitosamente
# 7
# guardado exitosamente
# 8
# guardado exitosamente
# 9
# guardado exitosamente
# 10
# guardado exitosamente
# 11
# guardado exitosamente
# 12
# guardado exitosamente
# 13
# guardado exitosamente
# 14
# guardado exitosamente
# 15
# guardado exitosamente
# 16
# guardado exitosamente
# 17
# guardado exitosamente
# 18
# guardado exitosamente
# 19
# guardado exitosamente
# 20
# guardado exitosamente
# 21
# guardado exitosamente
# 22
# guardado exitosamente
# 23
# guardado exitosamente
# 24
# guardado exitosamente
# 25
# guardado exitosamente
# 26
# guardado exitosamente
# 27
# guardado exitosamente
# 28
# guardado exitosamente
# 29
# guardado exitosamente
# 30
# guardado exitosamente
# 31
# guardado exitosamente
# 32
# guardado exitosamente
# 33
# guardado exitosamente
# 34
# guardado exitosamente
# 35
# guardado exitosamente
# 36
# guardado exitosamente
# 37
# guardado exitosamente
# 38
# guardado exitosamente
# 39
# guardado exitosamente
# 40
# guardado exitosamente
# 41
# guardado exitosamente
# 42
# guardado exitosamente
# 43
# guardado exitosamente
# 44
# guardado exitosamente
# 45
# guardado exitosamente
# 46
# guardado exitosamente
# 47
# guardado exitosamente
# 48
# guardado exitosamente
# 49
# guardado exitosamente
# 50
# guardado exitosamente
# 51
# guardado exitosamente
# 52
# guardado exitosamente
# 53
# guardado exitosamente
# 54
# guardado exitosamente
# 55
# guardado exitosamente
# 56
# guardado exitosamente
# 57
# guardado exitosamente
# 58
# guardado exitosamente
# 59
# guardado exitosamente
# 60
# guardado exitosamente
# 61
# guardado exitosamente
# 62
# guardado exitosamente
# 63
# guardado exitosamente
# 64
# guardado exitosamente
# 65
# guardado exitosamente
# 66
# guardado exitosamente
# 67
# guardado exitosamente
# 68
# guardado exitosamente
# 69
# guardado exitosamente
# 70
# guardado exitosamente
# 71
# guardado exitosamente
# 72
